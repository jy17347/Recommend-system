# %%
import time, os
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from get_dataset import load_dataset
from get_dataset import get_trainset
from embedding import embedding_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import metrics as MET
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
lr = 0.00003
epochs = 300
batch_size = 64

# %%
created_time = int(time.time()) 
chest_list, chest_dataset = load_dataset('exercise')
user_dataset = load_dataset('user')

num_chest_dataset = len(chest_dataset[0])
num_user_dataset = len(user_dataset[0])

# %%
user_train_input, chest_train_input, chest_label = get_trainset(user_dataset, chest_list, chest_dataset)
print(np.shape(user_train_input),np.shape(chest_train_input),np.shape(chest_label))

print(chest_label)
# Out:
# (200880,) (200880,) (200880,)
# [0 0 0 ... 0 0 0]

# %%
cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.00001, patience=5, verbose=1, mode='min',
    baseline=None, restore_best_weights=True
)

# %%
model = embedding_model(num_user_dataset,num_chest_dataset)
model.summary()

plot_model(model, show_shapes=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 11), dtype=tf.float32, name=None), name='multiply/mul:0', description="created by layer 'multiply'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  user_unput (InputLayer)        [(None, 1)]          0           []
#
#  item_input (InputLayer)        [(None, 1)]          0           []
#
#  embedding_3 (Embedding)        (None, 1, 11)        154000      ['user_unput[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 11)        176         ['item_input[0][0]']
#
#  flatten_2 (Flatten)            (None, 11)           0           ['embedding_3[0][0]']
#
#  flatten_3 (Flatten)            (None, 11)           0           ['embedding_1[0][0]']
#
#  concatenate (Concatenate)      (None, 22)           0           ['flatten_2[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  layer0 (Dense)                 (None, 32)           736         ['concatenate[0][0]']
#
#  layer1 (Dense)                 (None, 64)           2112        ['layer0[0][0]']
#
#  embedding_2 (Embedding)        (None, 1, 11)        154000      ['user_unput[0][0]']
#
#  embedding (Embedding)          (None, 1, 11)        176         ['item_input[0][0]']
#
#  layer2 (Dense)                 (None, 32)           2080        ['layer1[0][0]']
#
#  flatten (Flatten)              (None, 11)           0           ['embedding_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 11)           0           ['embedding[0][0]']
#
#  layer3 (Dense)                 (None, 16)           528         ['layer2[0][0]']
#
#  multiply (Multiply)            (None, 11)           0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  layer4 (Dense)                 (None, 8)            136         ['layer3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 19)           0           ['multiply[0][0]',
#                                                                   'layer4[0][0]']
#
#  prediction (Dense)             (None, 1)            20          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 313,964
# Trainable params: 313,964
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train, x_val, y_train, y_val, label_train, label_val = train_test_split(user_train_input, chest_train_input, chest_label, test_size=0.2, random_state=2022)

# %%
print(np.shape(x_train))
print(np.shape(y_train))
print(np.shape(label_train))
# Out:
# (160704,)
# (160704,)
# (160704,)

# %%
loss = 'binary_crossentropy'
model.compile(optimizer=Adam(learning_rate = lr), loss=loss, metrics=[MET.Precision(),MET.Recall(), MET.AUC()])
history = model.fit([x_train, y_train], label_train, epochs=epochs, batch_size = batch_size, validation_data=([x_val, y_val], label_val), callbacks=[cb])
# Out:
# Epoch 1/300
# 2511/2511 [==============================] - 12s 4ms/step - loss: 0.6013 - precision: 0.2485 - recall: 0.0029 - auc: 0.5431 - val_loss: 0.5667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6051
# Epoch 2/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.5625 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6162 - val_loss: 0.5652 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6007
# Epoch 3/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.5615 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6230 - val_loss: 0.5653 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5968
# Epoch 4/300
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.5609 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6314 - val_loss: 0.5653 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5963
# Epoch 5/300
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.5601 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6428 - val_loss: 0.5653 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5986
# Epoch 6/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.5586 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6572 - val_loss: 0.5651 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6042
# Epoch 7/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.5560 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6759 - val_loss: 0.5636 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6146
# Epoch 8/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.5501 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6941 - val_loss: 0.5590 - val_precision: 0.6667 - val_recall: 1.8430e-04 - val_auc: 0.6302
# Epoch 9/300
# 2511/2511 [==============================] - 11s 5ms/step - loss: 0.5352 - precision: 0.8686 - recall: 0.0571 - auc: 0.7144 - val_loss: 0.5448 - val_precision: 0.7187 - val_recall: 0.1133 - val_auc: 0.6610
# Epoch 10/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.4911 - precision: 0.7898 - recall: 0.2614 - auc: 0.7812 - val_loss: 0.4995 - val_precision: 0.6580 - val_recall: 0.2541 - val_auc: 0.7556
# Epoch 11/300
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.4218 - precision: 0.7471 - recall: 0.3929 - auc: 0.8503 - val_loss: 0.4651 - val_precision: 0.6269 - val_recall: 0.3692 - val_auc: 0.7959
# Epoch 12/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.3750 - precision: 0.7377 - recall: 0.5286 - auc: 0.8837 - val_loss: 0.4437 - val_precision: 0.6390 - val_recall: 0.4318 - val_auc: 0.8241
# Epoch 13/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.3383 - precision: 0.7501 - recall: 0.6162 - auc: 0.9081 - val_loss: 0.4253 - val_precision: 0.6595 - val_recall: 0.4806 - val_auc: 0.8483
# Epoch 14/300
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.3055 - precision: 0.7616 - recall: 0.7006 - auc: 0.9263 - val_loss: 0.4073 - val_precision: 0.6738 - val_recall: 0.5466 - val_auc: 0.8679
# Epoch 15/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.2760 - precision: 0.7735 - recall: 0.7743 - auc: 0.9400 - val_loss: 0.3899 - val_precision: 0.6825 - val_recall: 0.6320 - val_auc: 0.8820
# Epoch 16/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.2506 - precision: 0.7847 - recall: 0.8247 - auc: 0.9501 - val_loss: 0.3794 - val_precision: 0.6954 - val_recall: 0.6553 - val_auc: 0.8917
# Epoch 17/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.2294 - precision: 0.7947 - recall: 0.8566 - auc: 0.9577 - val_loss: 0.3733 - val_precision: 0.7076 - val_recall: 0.6622 - val_auc: 0.8986
# Epoch 18/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.2114 - precision: 0.8056 - recall: 0.8793 - auc: 0.9638 - val_loss: 0.3631 - val_precision: 0.7166 - val_recall: 0.7104 - val_auc: 0.9043
# Epoch 19/300
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.1961 - precision: 0.8144 - recall: 0.8939 - auc: 0.9686 - val_loss: 0.3589 - val_precision: 0.7239 - val_recall: 0.7204 - val_auc: 0.9085
# Epoch 20/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.1828 - precision: 0.8232 - recall: 0.9057 - auc: 0.9726 - val_loss: 0.3586 - val_precision: 0.7295 - val_recall: 0.7177 - val_auc: 0.9116
# Epoch 21/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.1713 - precision: 0.8306 - recall: 0.9114 - auc: 0.9761 - val_loss: 0.3582 - val_precision: 0.7346 - val_recall: 0.7255 - val_auc: 0.9148
# Epoch 22/300
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.1611 - precision: 0.8363 - recall: 0.9183 - auc: 0.9789 - val_loss: 0.3637 - val_precision: 0.7359 - val_recall: 0.7000 - val_auc: 0.9166
# Epoch 23/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.1524 - precision: 0.8436 - recall: 0.9240 - auc: 0.9810 - val_loss: 0.3654 - val_precision: 0.7369 - val_recall: 0.7015 - val_auc: 0.9188
# Epoch 24/300
# 2511/2511 [==============================] - 12s 5ms/step - loss: 0.1446 - precision: 0.8494 - recall: 0.9279 - auc: 0.9829 - val_loss: 0.3688 - val_precision: 0.7406 - val_recall: 0.6932 - val_auc: 0.9205
# Epoch 25/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.1376 - precision: 0.8549 - recall: 0.9309 - auc: 0.9846 - val_loss: 0.3605 - val_precision: 0.7448 - val_recall: 0.7432 - val_auc: 0.9229
# Epoch 26/300
# 2504/2511 [============================>.] - ETA: 0s - loss: 0.1310 - precision: 0.8607 - recall: 0.9335 - auc: 0.9861Restoring model weights from the end of the best epoch: 21.
# 2511/2511 [==============================] - 11s 4ms/step - loss: 0.1311 - precision: 0.8607 - recall: 0.9334 - auc: 0.9861 - val_loss: 0.3663 - val_precision: 0.7444 - val_recall: 0.7221 - val_auc: 0.9239
# Epoch 00026: early stopping

# %%
os.mkdir(f"model/{created_time}_{loss}_{lr}_{batch_size}")
model.save(f'model/{created_time}_{loss}_{lr}_{batch_size}/exercise_model.h5')
# Out:
# c:\Users\wooyong\anaconda3\envs\kwix\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
plt.figure(figsize=(25,4), facecolor='white')
plt.subplot(1,3,1)
pd.Series(history.history['loss']).plot(logy=True)
pd.Series(history.history['val_loss']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Train Error")

plt.subplot(1,3,2)
pd.Series(history.history['recall']).plot(logy=True)
pd.Series(history.history['val_recall']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Recall")

plt.subplot(1,3,3)
pd.Series(history.history['precision']).plot(logy=True)
pd.Series(history.history['val_precision']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.savefig(f"model/{created_time}_{loss}_{lr}_{batch_size}/metrics.png")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

label_pre = model.predict([x_val, y_val])


# #Create confusion matrix and normalizes it over predicted (columns)
# label = np.argmax(label_val, axis = 1)

label_pre = np.round(label_pre,0)
result = confusion_matrix(label_val, label_pre)
print(result)

import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
plt.figure(facecolor='white')
ax = sns.heatmap(result, annot=True,fmt='d',cmap='Blues',norm=LogNorm())
plt.title('Heatmap', fontsize=20)
plt.savefig(f"model/{created_time}_{loss}_{lr}_{batch_size}/heatmap.png")
plt.show()
# Out:
# [[26480  2844]
#  [ 2979  7873]]
