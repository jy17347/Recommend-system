# %%
import time, os
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from get_dataset import load_dataset
from get_dataset import get_trainset
from get_dataset import scaler_user
from embedding import embedding_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import metrics as MET
# Out:
# (13392, 11)
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
lr = 0.00003
epochs = 300
batch_size = 64

# %%
created_time = int(time.time()) 
chest_list, chest_dataset = load_dataset('exercise')
user_dataset = scaler_user(load_dataset('user'))

num_chest_dataset = len(chest_dataset[0])
num_user_dataset = len(user_dataset[0])

# %%
user_train_input, chest_train_input, chest_label = get_trainset(user_dataset, chest_list, chest_dataset)
print(np.shape(user_train_input),np.shape(chest_train_input),np.shape(chest_label))

print(chest_label)
# Out:
# (200880, 11) (200880,) (200880,)
# [0 0 0 ... 0 0 0]

# %%
cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.00001, patience=5, verbose=1, mode='min',
    baseline=None, restore_best_weights=True
)

# %%
model = embedding_model(num_user_dataset,num_chest_dataset)
model.summary()

plot_model(model, show_shapes=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 11), dtype=tf.float32, name=None), name='multiply/mul:0', description="created by layer 'multiply'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  item_input (InputLayer)        [(None, 1)]          0           []
#
#  embedding_1 (Embedding)        (None, 1, 11)        176         ['item_input[0][0]']
#
#  user_unput (InputLayer)        [(None, 11)]         0           []
#
#  flatten_1 (Flatten)            (None, 11)           0           ['embedding_1[0][0]']
#
#  concatenate (Concatenate)      (None, 22)           0           ['user_unput[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  layer0 (Dense)                 (None, 32)           736         ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['layer0[0][0]']
#
#  layer1 (Dense)                 (None, 64)           2112        ['dropout[0][0]']
#
#  embedding (Embedding)          (None, 1, 11)        176         ['item_input[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['layer1[0][0]']
#
#  flatten (Flatten)              (None, 11)           0           ['embedding[0][0]']
#
#  layer2 (Dense)                 (None, 32)           2080        ['dropout_1[0][0]']
#
#  multiply (Multiply)            (None, 11)           0           ['user_unput[0][0]',
#                                                                   'flatten[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['layer2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 43)           0           ['multiply[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  prediction (Dense)             (None, 1)            44          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 5,324
# Trainable params: 5,324
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train, x_val, y_train, y_val, label_train, label_val = train_test_split(user_train_input, chest_train_input, chest_label, test_size=0.2, random_state=2022)

# %%
print(np.shape(x_train))
print(np.shape(y_train))
print(np.shape(label_train))
# Out:
# (160704, 11)
# (160704,)
# (160704,)

# %%
loss = 'binary_crossentropy'
model.compile(optimizer=Adam(learning_rate = lr), loss=loss, metrics=[MET.Precision(),MET.Recall(), MET.AUC()])
history = model.fit([x_train, y_train], label_train, epochs=epochs, batch_size = batch_size, validation_data=([x_val, y_val], label_val), callbacks=[cb])
# Out:
# Epoch 1/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.6065 - precision: 0.2874 - recall: 0.0049 - auc: 0.5095 - val_loss: 0.5789 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5635
# Epoch 2/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.5761 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5776 - val_loss: 0.5643 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6383
# Epoch 3/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.5627 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6321 - val_loss: 0.5543 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6552
# Epoch 4/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.5534 - precision: 0.7500 - recall: 1.3821e-04 - auc: 0.6562 - val_loss: 0.5443 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6867
# Epoch 5/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.5424 - precision: 0.6923 - recall: 0.0027 - auc: 0.6834 - val_loss: 0.5289 - val_precision: 0.7528 - val_recall: 0.0062 - val_auc: 0.7278
# Epoch 6/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.5259 - precision: 0.6958 - recall: 0.0213 - auc: 0.7190 - val_loss: 0.5070 - val_precision: 0.7222 - val_recall: 0.0604 - val_auc: 0.7699
# Epoch 7/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.5062 - precision: 0.6903 - recall: 0.0960 - auc: 0.7534 - val_loss: 0.4811 - val_precision: 0.7065 - val_recall: 0.1978 - val_auc: 0.8011
# Epoch 8/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4845 - precision: 0.6786 - recall: 0.2139 - auc: 0.7825 - val_loss: 0.4566 - val_precision: 0.6937 - val_recall: 0.2845 - val_auc: 0.8232
# Epoch 9/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4670 - precision: 0.6666 - recall: 0.3228 - auc: 0.8014 - val_loss: 0.4387 - val_precision: 0.6872 - val_recall: 0.4096 - val_auc: 0.8371
# Epoch 10/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4532 - precision: 0.6625 - recall: 0.4058 - auc: 0.8153 - val_loss: 0.4267 - val_precision: 0.6849 - val_recall: 0.4726 - val_auc: 0.8448
# Epoch 11/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4446 - precision: 0.6567 - recall: 0.4490 - auc: 0.8230 - val_loss: 0.4193 - val_precision: 0.6761 - val_recall: 0.5094 - val_auc: 0.8493
# Epoch 12/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4375 - precision: 0.6544 - recall: 0.4812 - auc: 0.8295 - val_loss: 0.4145 - val_precision: 0.6760 - val_recall: 0.5205 - val_auc: 0.8521
# Epoch 13/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4327 - precision: 0.6535 - recall: 0.4974 - auc: 0.8341 - val_loss: 0.4112 - val_precision: 0.6771 - val_recall: 0.5280 - val_auc: 0.8541
# Epoch 14/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4284 - precision: 0.6573 - recall: 0.5101 - auc: 0.8380 - val_loss: 0.4091 - val_precision: 0.6679 - val_recall: 0.5520 - val_auc: 0.8554
# Epoch 15/300
# 2511/2511 [==============================] - 5s 2ms/step - loss: 0.4254 - precision: 0.6551 - recall: 0.5218 - auc: 0.8405 - val_loss: 0.4073 - val_precision: 0.6716 - val_recall: 0.5459 - val_auc: 0.8565
# Epoch 16/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4230 - precision: 0.6569 - recall: 0.5260 - auc: 0.8425 - val_loss: 0.4061 - val_precision: 0.6651 - val_recall: 0.5605 - val_auc: 0.8575
# Epoch 17/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4212 - precision: 0.6563 - recall: 0.5338 - auc: 0.8442 - val_loss: 0.4050 - val_precision: 0.6647 - val_recall: 0.5619 - val_auc: 0.8583
# Epoch 18/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4194 - precision: 0.6560 - recall: 0.5381 - auc: 0.8457 - val_loss: 0.4041 - val_precision: 0.6660 - val_recall: 0.5636 - val_auc: 0.8589
# Epoch 19/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4176 - precision: 0.6607 - recall: 0.5416 - auc: 0.8473 - val_loss: 0.4032 - val_precision: 0.6681 - val_recall: 0.5590 - val_auc: 0.8595
# Epoch 20/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4166 - precision: 0.6573 - recall: 0.5449 - auc: 0.8483 - val_loss: 0.4026 - val_precision: 0.6669 - val_recall: 0.5665 - val_auc: 0.8600
# Epoch 21/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4149 - precision: 0.6594 - recall: 0.5473 - auc: 0.8496 - val_loss: 0.4019 - val_precision: 0.6655 - val_recall: 0.5715 - val_auc: 0.8606
# Epoch 22/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4139 - precision: 0.6615 - recall: 0.5500 - auc: 0.8503 - val_loss: 0.4014 - val_precision: 0.6641 - val_recall: 0.5767 - val_auc: 0.8610
# Epoch 23/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4128 - precision: 0.6599 - recall: 0.5530 - auc: 0.8514 - val_loss: 0.4007 - val_precision: 0.6665 - val_recall: 0.5711 - val_auc: 0.8616
# Epoch 24/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4113 - precision: 0.6609 - recall: 0.5551 - auc: 0.8528 - val_loss: 0.4002 - val_precision: 0.6648 - val_recall: 0.5746 - val_auc: 0.8621
# Epoch 25/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4100 - precision: 0.6647 - recall: 0.5581 - auc: 0.8538 - val_loss: 0.3993 - val_precision: 0.6643 - val_recall: 0.5770 - val_auc: 0.8626
# Epoch 26/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4099 - precision: 0.6617 - recall: 0.5575 - auc: 0.8539 - val_loss: 0.3986 - val_precision: 0.6677 - val_recall: 0.5737 - val_auc: 0.8633
# Epoch 27/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4082 - precision: 0.6621 - recall: 0.5594 - auc: 0.8552 - val_loss: 0.3979 - val_precision: 0.6658 - val_recall: 0.5805 - val_auc: 0.8640
# Epoch 28/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.4072 - precision: 0.6627 - recall: 0.5609 - auc: 0.8561 - val_loss: 0.3973 - val_precision: 0.6654 - val_recall: 0.5852 - val_auc: 0.8644
# Epoch 29/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4061 - precision: 0.6636 - recall: 0.5650 - auc: 0.8570 - val_loss: 0.3964 - val_precision: 0.6654 - val_recall: 0.5880 - val_auc: 0.8652
# Epoch 30/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4056 - precision: 0.6656 - recall: 0.5683 - auc: 0.8578 - val_loss: 0.3953 - val_precision: 0.6709 - val_recall: 0.5781 - val_auc: 0.8660
# Epoch 31/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4042 - precision: 0.6670 - recall: 0.5668 - auc: 0.8589 - val_loss: 0.3947 - val_precision: 0.6677 - val_recall: 0.5913 - val_auc: 0.8668
# Epoch 32/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4037 - precision: 0.6671 - recall: 0.5696 - auc: 0.8594 - val_loss: 0.3939 - val_precision: 0.6672 - val_recall: 0.5974 - val_auc: 0.8676
# Epoch 33/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4020 - precision: 0.6680 - recall: 0.5715 - auc: 0.8607 - val_loss: 0.3928 - val_precision: 0.6675 - val_recall: 0.6019 - val_auc: 0.8683
# Epoch 34/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4015 - precision: 0.6675 - recall: 0.5749 - auc: 0.8611 - val_loss: 0.3918 - val_precision: 0.6731 - val_recall: 0.5940 - val_auc: 0.8692
# Epoch 35/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.4005 - precision: 0.6673 - recall: 0.5754 - auc: 0.8618 - val_loss: 0.3910 - val_precision: 0.6737 - val_recall: 0.5946 - val_auc: 0.8698
# Epoch 36/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3993 - precision: 0.6691 - recall: 0.5782 - auc: 0.8628 - val_loss: 0.3899 - val_precision: 0.6736 - val_recall: 0.5982 - val_auc: 0.8707
# Epoch 37/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3982 - precision: 0.6685 - recall: 0.5779 - auc: 0.8637 - val_loss: 0.3892 - val_precision: 0.6715 - val_recall: 0.6064 - val_auc: 0.8714
# Epoch 38/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3971 - precision: 0.6681 - recall: 0.5822 - auc: 0.8647 - val_loss: 0.3881 - val_precision: 0.6727 - val_recall: 0.6081 - val_auc: 0.8721
# Epoch 39/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3971 - precision: 0.6700 - recall: 0.5832 - auc: 0.8648 - val_loss: 0.3872 - val_precision: 0.6731 - val_recall: 0.6090 - val_auc: 0.8728
# Epoch 40/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3952 - precision: 0.6709 - recall: 0.5851 - auc: 0.8662 - val_loss: 0.3867 - val_precision: 0.6728 - val_recall: 0.6116 - val_auc: 0.8733
# Epoch 41/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3943 - precision: 0.6713 - recall: 0.5910 - auc: 0.8670 - val_loss: 0.3854 - val_precision: 0.6782 - val_recall: 0.6015 - val_auc: 0.8741
# Epoch 42/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3943 - precision: 0.6695 - recall: 0.5880 - auc: 0.8670 - val_loss: 0.3847 - val_precision: 0.6746 - val_recall: 0.6109 - val_auc: 0.8748
# Epoch 43/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3940 - precision: 0.6707 - recall: 0.5896 - auc: 0.8673 - val_loss: 0.3845 - val_precision: 0.6714 - val_recall: 0.6237 - val_auc: 0.8753
# Epoch 44/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3928 - precision: 0.6710 - recall: 0.5929 - auc: 0.8681 - val_loss: 0.3835 - val_precision: 0.6738 - val_recall: 0.6215 - val_auc: 0.8759
# Epoch 45/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3925 - precision: 0.6717 - recall: 0.5939 - auc: 0.8685 - val_loss: 0.3828 - val_precision: 0.6738 - val_recall: 0.6206 - val_auc: 0.8763
# Epoch 46/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3912 - precision: 0.6709 - recall: 0.5951 - auc: 0.8692 - val_loss: 0.3824 - val_precision: 0.6714 - val_recall: 0.6273 - val_auc: 0.8769
# Epoch 47/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3907 - precision: 0.6713 - recall: 0.5995 - auc: 0.8698 - val_loss: 0.3815 - val_precision: 0.6719 - val_recall: 0.6302 - val_auc: 0.8775
# Epoch 48/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3901 - precision: 0.6711 - recall: 0.6019 - auc: 0.8703 - val_loss: 0.3810 - val_precision: 0.6738 - val_recall: 0.6260 - val_auc: 0.8777
# Epoch 49/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3888 - precision: 0.6726 - recall: 0.6018 - auc: 0.8711 - val_loss: 0.3808 - val_precision: 0.6692 - val_recall: 0.6396 - val_auc: 0.8781
# Epoch 50/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3896 - precision: 0.6710 - recall: 0.6045 - auc: 0.8707 - val_loss: 0.3796 - val_precision: 0.6747 - val_recall: 0.6300 - val_auc: 0.8788
# Epoch 51/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3877 - precision: 0.6752 - recall: 0.6027 - auc: 0.8721 - val_loss: 0.3789 - val_precision: 0.6731 - val_recall: 0.6391 - val_auc: 0.8793
# Epoch 52/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3873 - precision: 0.6728 - recall: 0.6096 - auc: 0.8722 - val_loss: 0.3780 - val_precision: 0.6790 - val_recall: 0.6252 - val_auc: 0.8799
# Epoch 53/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3867 - precision: 0.6725 - recall: 0.6082 - auc: 0.8727 - val_loss: 0.3779 - val_precision: 0.6761 - val_recall: 0.6350 - val_auc: 0.8802
# Epoch 54/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3862 - precision: 0.6754 - recall: 0.6093 - auc: 0.8731 - val_loss: 0.3777 - val_precision: 0.6724 - val_recall: 0.6450 - val_auc: 0.8805
# Epoch 55/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3855 - precision: 0.6742 - recall: 0.6118 - auc: 0.8737 - val_loss: 0.3768 - val_precision: 0.6730 - val_recall: 0.6444 - val_auc: 0.8811
# Epoch 56/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3854 - precision: 0.6728 - recall: 0.6099 - auc: 0.8736 - val_loss: 0.3770 - val_precision: 0.6709 - val_recall: 0.6511 - val_auc: 0.8810
# Epoch 57/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3845 - precision: 0.6750 - recall: 0.6140 - auc: 0.8744 - val_loss: 0.3761 - val_precision: 0.6712 - val_recall: 0.6544 - val_auc: 0.8818
# Epoch 58/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3843 - precision: 0.6731 - recall: 0.6151 - auc: 0.8746 - val_loss: 0.3752 - val_precision: 0.6756 - val_recall: 0.6450 - val_auc: 0.8822
# Epoch 59/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3829 - precision: 0.6744 - recall: 0.6164 - auc: 0.8755 - val_loss: 0.3752 - val_precision: 0.6740 - val_recall: 0.6551 - val_auc: 0.8823
# Epoch 60/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3833 - precision: 0.6751 - recall: 0.6180 - auc: 0.8752 - val_loss: 0.3746 - val_precision: 0.6753 - val_recall: 0.6530 - val_auc: 0.8828
# Epoch 61/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3827 - precision: 0.6745 - recall: 0.6178 - auc: 0.8756 - val_loss: 0.3736 - val_precision: 0.6772 - val_recall: 0.6522 - val_auc: 0.8834
# Epoch 62/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3822 - precision: 0.6752 - recall: 0.6171 - auc: 0.8760 - val_loss: 0.3739 - val_precision: 0.6753 - val_recall: 0.6601 - val_auc: 0.8835
# Epoch 63/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3813 - precision: 0.6769 - recall: 0.6195 - auc: 0.8769 - val_loss: 0.3730 - val_precision: 0.6753 - val_recall: 0.6550 - val_auc: 0.8838
# Epoch 64/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3805 - precision: 0.6763 - recall: 0.6223 - auc: 0.8772 - val_loss: 0.3733 - val_precision: 0.6707 - val_recall: 0.6720 - val_auc: 0.8841
# Epoch 65/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3805 - precision: 0.6774 - recall: 0.6218 - auc: 0.8772 - val_loss: 0.3726 - val_precision: 0.6718 - val_recall: 0.6751 - val_auc: 0.8846
# Epoch 66/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3802 - precision: 0.6753 - recall: 0.6257 - auc: 0.8775 - val_loss: 0.3716 - val_precision: 0.6788 - val_recall: 0.6626 - val_auc: 0.8848
# Epoch 67/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3795 - precision: 0.6761 - recall: 0.6239 - auc: 0.8779 - val_loss: 0.3714 - val_precision: 0.6751 - val_recall: 0.6661 - val_auc: 0.8851
# Epoch 68/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3790 - precision: 0.6773 - recall: 0.6258 - auc: 0.8783 - val_loss: 0.3710 - val_precision: 0.6767 - val_recall: 0.6692 - val_auc: 0.8853
# Epoch 69/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3786 - precision: 0.6754 - recall: 0.6298 - auc: 0.8786 - val_loss: 0.3698 - val_precision: 0.6822 - val_recall: 0.6559 - val_auc: 0.8859
# Epoch 70/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3773 - precision: 0.6787 - recall: 0.6283 - auc: 0.8795 - val_loss: 0.3701 - val_precision: 0.6754 - val_recall: 0.6760 - val_auc: 0.8861
# Epoch 71/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3776 - precision: 0.6766 - recall: 0.6302 - auc: 0.8793 - val_loss: 0.3701 - val_precision: 0.6751 - val_recall: 0.6789 - val_auc: 0.8860
# Epoch 72/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3770 - precision: 0.6758 - recall: 0.6317 - auc: 0.8796 - val_loss: 0.3693 - val_precision: 0.6790 - val_recall: 0.6677 - val_auc: 0.8864
# Epoch 73/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3762 - precision: 0.6800 - recall: 0.6316 - auc: 0.8803 - val_loss: 0.3686 - val_precision: 0.6780 - val_recall: 0.6726 - val_auc: 0.8868
# Epoch 74/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3760 - precision: 0.6780 - recall: 0.6333 - auc: 0.8803 - val_loss: 0.3682 - val_precision: 0.6784 - val_recall: 0.6755 - val_auc: 0.8873
# Epoch 75/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3756 - precision: 0.6787 - recall: 0.6371 - auc: 0.8806 - val_loss: 0.3676 - val_precision: 0.6791 - val_recall: 0.6753 - val_auc: 0.8875
# Epoch 76/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3751 - precision: 0.6782 - recall: 0.6359 - auc: 0.8809 - val_loss: 0.3674 - val_precision: 0.6777 - val_recall: 0.6822 - val_auc: 0.8878
# Epoch 77/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3748 - precision: 0.6809 - recall: 0.6370 - auc: 0.8811 - val_loss: 0.3678 - val_precision: 0.6765 - val_recall: 0.6904 - val_auc: 0.8880
# Epoch 78/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3745 - precision: 0.6800 - recall: 0.6382 - auc: 0.8814 - val_loss: 0.3672 - val_precision: 0.6754 - val_recall: 0.6945 - val_auc: 0.8883
# Epoch 79/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3736 - precision: 0.6809 - recall: 0.6388 - auc: 0.8818 - val_loss: 0.3665 - val_precision: 0.6770 - val_recall: 0.6895 - val_auc: 0.8884
# Epoch 80/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3730 - precision: 0.6794 - recall: 0.6424 - auc: 0.8822 - val_loss: 0.3661 - val_precision: 0.6801 - val_recall: 0.6849 - val_auc: 0.8889
# Epoch 81/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3734 - precision: 0.6812 - recall: 0.6407 - auc: 0.8820 - val_loss: 0.3654 - val_precision: 0.6796 - val_recall: 0.6889 - val_auc: 0.8892
# Epoch 82/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3725 - precision: 0.6801 - recall: 0.6427 - auc: 0.8827 - val_loss: 0.3646 - val_precision: 0.6818 - val_recall: 0.6792 - val_auc: 0.8895
# Epoch 83/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3724 - precision: 0.6822 - recall: 0.6433 - auc: 0.8827 - val_loss: 0.3647 - val_precision: 0.6815 - val_recall: 0.6871 - val_auc: 0.8898
# Epoch 84/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3717 - precision: 0.6805 - recall: 0.6443 - auc: 0.8832 - val_loss: 0.3639 - val_precision: 0.6810 - val_recall: 0.6855 - val_auc: 0.8900
# Epoch 85/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3713 - precision: 0.6811 - recall: 0.6445 - auc: 0.8835 - val_loss: 0.3639 - val_precision: 0.6796 - val_recall: 0.6900 - val_auc: 0.8900
# Epoch 86/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3705 - precision: 0.6830 - recall: 0.6463 - auc: 0.8840 - val_loss: 0.3635 - val_precision: 0.6796 - val_recall: 0.6943 - val_auc: 0.8903
# Epoch 87/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3705 - precision: 0.6814 - recall: 0.6449 - auc: 0.8840 - val_loss: 0.3634 - val_precision: 0.6777 - val_recall: 0.7024 - val_auc: 0.8906
# Epoch 88/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3701 - precision: 0.6814 - recall: 0.6463 - auc: 0.8842 - val_loss: 0.3636 - val_precision: 0.6740 - val_recall: 0.7123 - val_auc: 0.8909
# Epoch 89/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3702 - precision: 0.6813 - recall: 0.6490 - auc: 0.8842 - val_loss: 0.3620 - val_precision: 0.6825 - val_recall: 0.6931 - val_auc: 0.8912
# Epoch 90/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3689 - precision: 0.6819 - recall: 0.6491 - auc: 0.8849 - val_loss: 0.3619 - val_precision: 0.6810 - val_recall: 0.6977 - val_auc: 0.8914
# Epoch 91/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3694 - precision: 0.6813 - recall: 0.6490 - auc: 0.8846 - val_loss: 0.3611 - val_precision: 0.6824 - val_recall: 0.6956 - val_auc: 0.8919
# Epoch 92/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3690 - precision: 0.6815 - recall: 0.6483 - auc: 0.8850 - val_loss: 0.3614 - val_precision: 0.6776 - val_recall: 0.7090 - val_auc: 0.8919
# Epoch 93/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3687 - precision: 0.6838 - recall: 0.6544 - auc: 0.8853 - val_loss: 0.3609 - val_precision: 0.6853 - val_recall: 0.6907 - val_auc: 0.8918
# Epoch 94/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3682 - precision: 0.6845 - recall: 0.6499 - auc: 0.8856 - val_loss: 0.3612 - val_precision: 0.6777 - val_recall: 0.7143 - val_auc: 0.8923
# Epoch 95/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3674 - precision: 0.6820 - recall: 0.6528 - auc: 0.8860 - val_loss: 0.3612 - val_precision: 0.6781 - val_recall: 0.7142 - val_auc: 0.8922
# Epoch 96/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3668 - precision: 0.6842 - recall: 0.6566 - auc: 0.8864 - val_loss: 0.3595 - val_precision: 0.6808 - val_recall: 0.7133 - val_auc: 0.8929
# Epoch 97/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3668 - precision: 0.6835 - recall: 0.6578 - auc: 0.8864 - val_loss: 0.3596 - val_precision: 0.6819 - val_recall: 0.7125 - val_auc: 0.8928
# Epoch 98/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3668 - precision: 0.6834 - recall: 0.6581 - auc: 0.8866 - val_loss: 0.3588 - val_precision: 0.6847 - val_recall: 0.7050 - val_auc: 0.8933
# Epoch 99/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3661 - precision: 0.6841 - recall: 0.6567 - auc: 0.8869 - val_loss: 0.3593 - val_precision: 0.6790 - val_recall: 0.7183 - val_auc: 0.8932
# Epoch 100/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3663 - precision: 0.6828 - recall: 0.6598 - auc: 0.8867 - val_loss: 0.3582 - val_precision: 0.6861 - val_recall: 0.7013 - val_auc: 0.8936
# Epoch 101/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3663 - precision: 0.6851 - recall: 0.6578 - auc: 0.8869 - val_loss: 0.3583 - val_precision: 0.6825 - val_recall: 0.7128 - val_auc: 0.8940
# Epoch 102/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3650 - precision: 0.6855 - recall: 0.6611 - auc: 0.8876 - val_loss: 0.3584 - val_precision: 0.6801 - val_recall: 0.7210 - val_auc: 0.8941
# Epoch 103/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3651 - precision: 0.6837 - recall: 0.6594 - auc: 0.8875 - val_loss: 0.3578 - val_precision: 0.6824 - val_recall: 0.7144 - val_auc: 0.8941
# Epoch 104/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3648 - precision: 0.6845 - recall: 0.6618 - auc: 0.8878 - val_loss: 0.3574 - val_precision: 0.6848 - val_recall: 0.7089 - val_auc: 0.8940
# Epoch 105/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3652 - precision: 0.6843 - recall: 0.6608 - auc: 0.8875 - val_loss: 0.3569 - val_precision: 0.6844 - val_recall: 0.7133 - val_auc: 0.8945
# Epoch 106/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3643 - precision: 0.6857 - recall: 0.6646 - auc: 0.8881 - val_loss: 0.3572 - val_precision: 0.6816 - val_recall: 0.7195 - val_auc: 0.8944
# Epoch 107/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3641 - precision: 0.6842 - recall: 0.6630 - auc: 0.8883 - val_loss: 0.3571 - val_precision: 0.6828 - val_recall: 0.7200 - val_auc: 0.8946
# Epoch 108/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3633 - precision: 0.6873 - recall: 0.6652 - auc: 0.8887 - val_loss: 0.3561 - val_precision: 0.6856 - val_recall: 0.7122 - val_auc: 0.8946
# Epoch 109/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3633 - precision: 0.6869 - recall: 0.6645 - auc: 0.8889 - val_loss: 0.3554 - val_precision: 0.6887 - val_recall: 0.7036 - val_auc: 0.8947
# Epoch 110/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3633 - precision: 0.6848 - recall: 0.6658 - auc: 0.8885 - val_loss: 0.3559 - val_precision: 0.6843 - val_recall: 0.7180 - val_auc: 0.8952
# Epoch 111/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3638 - precision: 0.6853 - recall: 0.6647 - auc: 0.8884 - val_loss: 0.3558 - val_precision: 0.6839 - val_recall: 0.7194 - val_auc: 0.8953
# Epoch 112/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3625 - precision: 0.6860 - recall: 0.6672 - auc: 0.8893 - val_loss: 0.3558 - val_precision: 0.6796 - val_recall: 0.7297 - val_auc: 0.8955
# Epoch 113/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3626 - precision: 0.6884 - recall: 0.6675 - auc: 0.8893 - val_loss: 0.3569 - val_precision: 0.6761 - val_recall: 0.7330 - val_auc: 0.8952
# Epoch 114/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3629 - precision: 0.6853 - recall: 0.6672 - auc: 0.8890 - val_loss: 0.3543 - val_precision: 0.6893 - val_recall: 0.7039 - val_auc: 0.8958
# Epoch 115/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3626 - precision: 0.6871 - recall: 0.6675 - auc: 0.8893 - val_loss: 0.3549 - val_precision: 0.6870 - val_recall: 0.7151 - val_auc: 0.8958
# Epoch 116/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3627 - precision: 0.6870 - recall: 0.6682 - auc: 0.8892 - val_loss: 0.3556 - val_precision: 0.6808 - val_recall: 0.7308 - val_auc: 0.8958
# Epoch 117/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3620 - precision: 0.6872 - recall: 0.6680 - auc: 0.8896 - val_loss: 0.3550 - val_precision: 0.6831 - val_recall: 0.7270 - val_auc: 0.8958
# Epoch 118/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.3618 - precision: 0.6872 - recall: 0.6678 - auc: 0.8897 - val_loss: 0.3549 - val_precision: 0.6827 - val_recall: 0.7271 - val_auc: 0.8960
# Epoch 119/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3610 - precision: 0.6889 - recall: 0.6722 - auc: 0.8902 - val_loss: 0.3542 - val_precision: 0.6837 - val_recall: 0.7246 - val_auc: 0.8962
# Epoch 120/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3614 - precision: 0.6881 - recall: 0.6701 - auc: 0.8899 - val_loss: 0.3544 - val_precision: 0.6825 - val_recall: 0.7283 - val_auc: 0.8962
# Epoch 121/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3611 - precision: 0.6869 - recall: 0.6722 - auc: 0.8901 - val_loss: 0.3535 - val_precision: 0.6870 - val_recall: 0.7179 - val_auc: 0.8965
# Epoch 122/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3606 - precision: 0.6885 - recall: 0.6737 - auc: 0.8906 - val_loss: 0.3529 - val_precision: 0.6881 - val_recall: 0.7140 - val_auc: 0.8966
# Epoch 123/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3607 - precision: 0.6869 - recall: 0.6721 - auc: 0.8905 - val_loss: 0.3529 - val_precision: 0.6873 - val_recall: 0.7197 - val_auc: 0.8968
# Epoch 124/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3609 - precision: 0.6876 - recall: 0.6737 - auc: 0.8904 - val_loss: 0.3531 - val_precision: 0.6881 - val_recall: 0.7200 - val_auc: 0.8969
# Epoch 125/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3607 - precision: 0.6881 - recall: 0.6734 - auc: 0.8905 - val_loss: 0.3529 - val_precision: 0.6895 - val_recall: 0.7152 - val_auc: 0.8968
# Epoch 126/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3603 - precision: 0.6881 - recall: 0.6711 - auc: 0.8907 - val_loss: 0.3533 - val_precision: 0.6880 - val_recall: 0.7212 - val_auc: 0.8969
# Epoch 127/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3596 - precision: 0.6903 - recall: 0.6743 - auc: 0.8912 - val_loss: 0.3527 - val_precision: 0.6863 - val_recall: 0.7258 - val_auc: 0.8972
# Epoch 128/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3592 - precision: 0.6898 - recall: 0.6740 - auc: 0.8916 - val_loss: 0.3532 - val_precision: 0.6824 - val_recall: 0.7329 - val_auc: 0.8972
# Epoch 129/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3594 - precision: 0.6889 - recall: 0.6741 - auc: 0.8914 - val_loss: 0.3528 - val_precision: 0.6834 - val_recall: 0.7293 - val_auc: 0.8971
# Epoch 130/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3599 - precision: 0.6880 - recall: 0.6740 - auc: 0.8911 - val_loss: 0.3522 - val_precision: 0.6857 - val_recall: 0.7255 - val_auc: 0.8971
# Epoch 131/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3590 - precision: 0.6891 - recall: 0.6759 - auc: 0.8915 - val_loss: 0.3521 - val_precision: 0.6855 - val_recall: 0.7318 - val_auc: 0.8976
# Epoch 132/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3595 - precision: 0.6887 - recall: 0.6771 - auc: 0.8912 - val_loss: 0.3523 - val_precision: 0.6867 - val_recall: 0.7260 - val_auc: 0.8976
# Epoch 133/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3591 - precision: 0.6902 - recall: 0.6750 - auc: 0.8915 - val_loss: 0.3512 - val_precision: 0.6897 - val_recall: 0.7205 - val_auc: 0.8976
# Epoch 134/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3588 - precision: 0.6896 - recall: 0.6757 - auc: 0.8918 - val_loss: 0.3517 - val_precision: 0.6881 - val_recall: 0.7221 - val_auc: 0.8977
# Epoch 135/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3592 - precision: 0.6882 - recall: 0.6750 - auc: 0.8914 - val_loss: 0.3513 - val_precision: 0.6887 - val_recall: 0.7259 - val_auc: 0.8977
# Epoch 136/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3594 - precision: 0.6893 - recall: 0.6784 - auc: 0.8913 - val_loss: 0.3522 - val_precision: 0.6850 - val_recall: 0.7272 - val_auc: 0.8974
# Epoch 137/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3584 - precision: 0.6902 - recall: 0.6762 - auc: 0.8920 - val_loss: 0.3523 - val_precision: 0.6833 - val_recall: 0.7362 - val_auc: 0.8979
# Epoch 138/300
# 2506/2511 [============================>.] - ETA: 0s - loss: 0.3581 - precision: 0.6911 - recall: 0.6769 - auc: 0.8922Restoring model weights from the end of the best epoch: 133.
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.3581 - precision: 0.6910 - recall: 0.6770 - auc: 0.8922 - val_loss: 0.3525 - val_precision: 0.6805 - val_recall: 0.7426 - val_auc: 0.8979
# Epoch 00138: early stopping

# %%
os.mkdir(f"model/{created_time}_{loss}_{lr}_{batch_size}")
model.save(f'model/{created_time}_{loss}_{lr}_{batch_size}/exercise_model.h5')
# Out:
# c:\Users\wooyong\anaconda3\envs\kwix\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
plt.figure(figsize=(25,4), facecolor='white')
plt.subplot(1,3,1)
pd.Series(history.history['loss']).plot(logy=True)
pd.Series(history.history['val_loss']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Train Error")

plt.subplot(1,3,2)
pd.Series(history.history['recall']).plot(logy=True)
pd.Series(history.history['val_recall']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Recall")

plt.subplot(1,3,3)
pd.Series(history.history['precision']).plot(logy=True)
pd.Series(history.history['val_precision']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.savefig(f"model/{created_time}_{loss}_{lr}_{batch_size}/metrics.png")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

label_pre = model.predict([x_val, y_val])


# #Create confusion matrix and normalizes it over predicted (columns)
# label = np.argmax(label_val, axis = 1)

label_pre = np.round(label_pre,0)
result = confusion_matrix(label_val, label_pre)
print(result)

import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
plt.figure(facecolor='white')
ax = sns.heatmap(result, annot=True,fmt='d',cmap='Blues',norm=LogNorm())
plt.title('Heatmap', fontsize=20)
plt.savefig(f"model/{created_time}_{loss}_{lr}_{batch_size}/heatmap.png")
plt.show()
# Out:
# [[25807  3517]
#  [ 3033  7819]]
