# %%
import time, os
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from get_dataset import load_dataset
from get_dataset import get_trainset
from get_dataset import scaler_user
from embedding import embedding_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import metrics as MET
# Out:
# (13392, 11)
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
lr = 0.00003
epochs = 300
batch_size = 64

# %%
created_time = int(time.time()) 
chest_list, chest_dataset = load_dataset('exercise')
user_dataset = scaler_user(load_dataset('user'))

num_chest_dataset = len(chest_dataset[0])
num_user_dataset = len(user_dataset[0])

# %%
user_train_input, chest_train_input, chest_label = get_trainset(user_dataset, chest_list, chest_dataset)
print(np.shape(user_train_input),np.shape(chest_train_input),np.shape(chest_label))

print(chest_label)
# Out:
# (200880, 11) (200880,) (200880,)
# [0 0 0 ... 0 0 0]

# %%
cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.00001, patience=5, verbose=1, mode='min',
    baseline=None, restore_best_weights=True
)

# %%
model = embedding_model(num_user_dataset,num_chest_dataset)
model.summary()

plot_model(model, show_shapes=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 11), dtype=tf.float32, name=None), name='multiply/mul:0', description="created by layer 'multiply'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  item_input (InputLayer)        [(None, 1)]          0           []
#
#  embedding_1 (Embedding)        (None, 1, 11)        176         ['item_input[0][0]']
#
#  user_unput (InputLayer)        [(None, 11)]         0           []
#
#  flatten_1 (Flatten)            (None, 11)           0           ['embedding_1[0][0]']
#
#  concatenate (Concatenate)      (None, 22)           0           ['user_unput[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  layer0 (Dense)                 (None, 32)           736         ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['layer0[0][0]']
#
#  layer1 (Dense)                 (None, 64)           2112        ['dropout[0][0]']
#
#  embedding (Embedding)          (None, 1, 11)        176         ['item_input[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['layer1[0][0]']
#
#  flatten (Flatten)              (None, 11)           0           ['embedding[0][0]']
#
#  layer2 (Dense)                 (None, 32)           2080        ['dropout_1[0][0]']
#
#  multiply (Multiply)            (None, 11)           0           ['user_unput[0][0]',
#                                                                   'flatten[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['layer2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 43)           0           ['multiply[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  prediction (Dense)             (None, 1)            44          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 5,324
# Trainable params: 5,324
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train, x_val, y_train, y_val, label_train, label_val = train_test_split(user_train_input, chest_train_input, chest_label, test_size=0.2, random_state=2022)

# %%
print(np.shape(x_train))
print(np.shape(y_train))
print(np.shape(label_train))
# Out:
# (160704, 11)
# (160704,)
# (160704,)

# %%
loss = 'binary_crossentropy'
model.compile(optimizer=Adam(learning_rate = lr), loss=loss, metrics=[MET.Precision(),MET.Recall(), MET.AUC()])
history = model.fit([x_train, y_train], label_train, epochs=epochs, batch_size = batch_size, validation_data=([x_val, y_val], label_val), callbacks=[cb])
# Out:
# Epoch 1/300
# 2511/2511 [==============================] - 8s 3ms/step - loss: 0.6248 - precision: 0.2700 - recall: 0.0793 - auc: 0.5018 - val_loss: 0.5810 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5620
# Epoch 2/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.5862 - precision: 0.2000 - recall: 6.9104e-05 - auc: 0.5424 - val_loss: 0.5714 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6227
# Epoch 3/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.5761 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5874 - val_loss: 0.5633 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6401
# Epoch 4/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.5690 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6171 - val_loss: 0.5586 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6597
# Epoch 5/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.5638 - precision: 1.0000 - recall: 4.6069e-05 - auc: 0.6341 - val_loss: 0.5538 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6784
# Epoch 6/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.5581 - precision: 0.5833 - recall: 1.6124e-04 - auc: 0.6498 - val_loss: 0.5467 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6976
# Epoch 7/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.5480 - precision: 0.8333 - recall: 0.0010 - auc: 0.6732 - val_loss: 0.5344 - val_precision: 1.0000 - val_recall: 9.2149e-04 - val_auc: 0.7240
# Epoch 8/300
# 2511/2511 [==============================] - 6s 2ms/step - loss: 0.5337 - precision: 0.7888 - recall: 0.0117 - auc: 0.7033 - val_loss: 0.5140 - val_precision: 0.7739 - val_recall: 0.0388 - val_auc: 0.7590
# Epoch 9/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.5141 - precision: 0.7393 - recall: 0.0830 - auc: 0.7391 - val_loss: 0.4869 - val_precision: 0.7170 - val_recall: 0.1737 - val_auc: 0.7927
# Epoch 10/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4922 - precision: 0.6702 - recall: 0.2299 - auc: 0.7700 - val_loss: 0.4610 - val_precision: 0.6722 - val_recall: 0.3515 - val_auc: 0.8167
# Epoch 11/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.4736 - precision: 0.6461 - recall: 0.3478 - auc: 0.7922 - val_loss: 0.4422 - val_precision: 0.6676 - val_recall: 0.4454 - val_auc: 0.8320
# Epoch 12/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.4612 - precision: 0.6440 - recall: 0.4105 - auc: 0.8055 - val_loss: 0.4306 - val_precision: 0.6665 - val_recall: 0.4837 - val_auc: 0.8407
# Epoch 13/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.4517 - precision: 0.6440 - recall: 0.4465 - auc: 0.8155 - val_loss: 0.4232 - val_precision: 0.6671 - val_recall: 0.5138 - val_auc: 0.8456
# Epoch 14/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.4449 - precision: 0.6487 - recall: 0.4732 - auc: 0.8223 - val_loss: 0.4178 - val_precision: 0.6651 - val_recall: 0.5337 - val_auc: 0.8492
# Epoch 15/300
# 2511/2511 [==============================] - 6s 3ms/step - loss: 0.4394 - precision: 0.6497 - recall: 0.4894 - auc: 0.8274 - val_loss: 0.4145 - val_precision: 0.6616 - val_recall: 0.5539 - val_auc: 0.8518
# Epoch 16/300
# 2511/2511 [==============================] - 8s 3ms/step - loss: 0.4354 - precision: 0.6503 - recall: 0.5022 - auc: 0.8314 - val_loss: 0.4111 - val_precision: 0.6681 - val_recall: 0.5419 - val_auc: 0.8538
# Epoch 17/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.4318 - precision: 0.6557 - recall: 0.5110 - auc: 0.8344 - val_loss: 0.4088 - val_precision: 0.6648 - val_recall: 0.5511 - val_auc: 0.8554
# Epoch 18/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4287 - precision: 0.6546 - recall: 0.5198 - auc: 0.8375 - val_loss: 0.4071 - val_precision: 0.6672 - val_recall: 0.5499 - val_auc: 0.8565
# Epoch 19/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4262 - precision: 0.6559 - recall: 0.5210 - auc: 0.8397 - val_loss: 0.4058 - val_precision: 0.6647 - val_recall: 0.5641 - val_auc: 0.8576
# Epoch 20/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4241 - precision: 0.6550 - recall: 0.5281 - auc: 0.8418 - val_loss: 0.4045 - val_precision: 0.6690 - val_recall: 0.5593 - val_auc: 0.8585
# Epoch 21/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4221 - precision: 0.6591 - recall: 0.5304 - auc: 0.8436 - val_loss: 0.4037 - val_precision: 0.6624 - val_recall: 0.5772 - val_auc: 0.8593
# Epoch 22/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4203 - precision: 0.6593 - recall: 0.5408 - auc: 0.8450 - val_loss: 0.4026 - val_precision: 0.6662 - val_recall: 0.5736 - val_auc: 0.8600
# Epoch 23/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4188 - precision: 0.6589 - recall: 0.5410 - auc: 0.8464 - val_loss: 0.4020 - val_precision: 0.6604 - val_recall: 0.5884 - val_auc: 0.8608
# Epoch 24/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4174 - precision: 0.6600 - recall: 0.5412 - auc: 0.8477 - val_loss: 0.4011 - val_precision: 0.6607 - val_recall: 0.5908 - val_auc: 0.8614
# Epoch 25/300
# 2511/2511 [==============================] - 8s 3ms/step - loss: 0.4163 - precision: 0.6633 - recall: 0.5474 - auc: 0.8488 - val_loss: 0.4003 - val_precision: 0.6607 - val_recall: 0.5927 - val_auc: 0.8619
# Epoch 26/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4145 - precision: 0.6635 - recall: 0.5488 - auc: 0.8504 - val_loss: 0.3995 - val_precision: 0.6600 - val_recall: 0.5950 - val_auc: 0.8626
# Epoch 27/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4130 - precision: 0.6626 - recall: 0.5538 - auc: 0.8518 - val_loss: 0.3985 - val_precision: 0.6598 - val_recall: 0.5949 - val_auc: 0.8634
# Epoch 28/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4123 - precision: 0.6642 - recall: 0.5535 - auc: 0.8520 - val_loss: 0.3979 - val_precision: 0.6593 - val_recall: 0.6005 - val_auc: 0.8639
# Epoch 29/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4113 - precision: 0.6632 - recall: 0.5556 - auc: 0.8530 - val_loss: 0.3970 - val_precision: 0.6608 - val_recall: 0.6009 - val_auc: 0.8646
# Epoch 30/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4103 - precision: 0.6628 - recall: 0.5590 - auc: 0.8541 - val_loss: 0.3963 - val_precision: 0.6584 - val_recall: 0.6092 - val_auc: 0.8652
# Epoch 31/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4093 - precision: 0.6639 - recall: 0.5636 - auc: 0.8550 - val_loss: 0.3956 - val_precision: 0.6582 - val_recall: 0.6156 - val_auc: 0.8659
# Epoch 32/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4087 - precision: 0.6636 - recall: 0.5613 - auc: 0.8554 - val_loss: 0.3946 - val_precision: 0.6613 - val_recall: 0.6091 - val_auc: 0.8665
# Epoch 33/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4075 - precision: 0.6662 - recall: 0.5653 - auc: 0.8565 - val_loss: 0.3936 - val_precision: 0.6634 - val_recall: 0.6089 - val_auc: 0.8673
# Epoch 34/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4061 - precision: 0.6666 - recall: 0.5676 - auc: 0.8575 - val_loss: 0.3931 - val_precision: 0.6589 - val_recall: 0.6213 - val_auc: 0.8680
# Epoch 35/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4056 - precision: 0.6654 - recall: 0.5683 - auc: 0.8581 - val_loss: 0.3922 - val_precision: 0.6582 - val_recall: 0.6238 - val_auc: 0.8687
# Epoch 36/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4046 - precision: 0.6704 - recall: 0.5714 - auc: 0.8588 - val_loss: 0.3913 - val_precision: 0.6607 - val_recall: 0.6273 - val_auc: 0.8695
# Epoch 37/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4036 - precision: 0.6680 - recall: 0.5753 - auc: 0.8596 - val_loss: 0.3902 - val_precision: 0.6619 - val_recall: 0.6247 - val_auc: 0.8701
# Epoch 38/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4025 - precision: 0.6695 - recall: 0.5743 - auc: 0.8607 - val_loss: 0.3896 - val_precision: 0.6608 - val_recall: 0.6365 - val_auc: 0.8709
# Epoch 39/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4009 - precision: 0.6684 - recall: 0.5786 - auc: 0.8617 - val_loss: 0.3883 - val_precision: 0.6646 - val_recall: 0.6323 - val_auc: 0.8718
# Epoch 40/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.4003 - precision: 0.6689 - recall: 0.5799 - auc: 0.8623 - val_loss: 0.3877 - val_precision: 0.6618 - val_recall: 0.6435 - val_auc: 0.8725
# Epoch 41/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3995 - precision: 0.6691 - recall: 0.5861 - auc: 0.8633 - val_loss: 0.3866 - val_precision: 0.6599 - val_recall: 0.6447 - val_auc: 0.8732
# Epoch 42/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3978 - precision: 0.6716 - recall: 0.5880 - auc: 0.8642 - val_loss: 0.3857 - val_precision: 0.6596 - val_recall: 0.6474 - val_auc: 0.8741
# Epoch 43/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3972 - precision: 0.6708 - recall: 0.5886 - auc: 0.8647 - val_loss: 0.3841 - val_precision: 0.6668 - val_recall: 0.6332 - val_auc: 0.8748
# Epoch 44/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3965 - precision: 0.6726 - recall: 0.5893 - auc: 0.8655 - val_loss: 0.3840 - val_precision: 0.6583 - val_recall: 0.6611 - val_auc: 0.8755
# Epoch 45/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3957 - precision: 0.6706 - recall: 0.5971 - auc: 0.8661 - val_loss: 0.3825 - val_precision: 0.6674 - val_recall: 0.6445 - val_auc: 0.8762
# Epoch 46/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3954 - precision: 0.6713 - recall: 0.5932 - auc: 0.8664 - val_loss: 0.3816 - val_precision: 0.6655 - val_recall: 0.6511 - val_auc: 0.8769
# Epoch 47/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3948 - precision: 0.6718 - recall: 0.5939 - auc: 0.8669 - val_loss: 0.3813 - val_precision: 0.6610 - val_recall: 0.6688 - val_auc: 0.8777
# Epoch 48/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3934 - precision: 0.6711 - recall: 0.5988 - auc: 0.8679 - val_loss: 0.3799 - val_precision: 0.6665 - val_recall: 0.6579 - val_auc: 0.8784
# Epoch 49/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3917 - precision: 0.6739 - recall: 0.6010 - auc: 0.8691 - val_loss: 0.3789 - val_precision: 0.6655 - val_recall: 0.6668 - val_auc: 0.8792
# Epoch 50/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3912 - precision: 0.6740 - recall: 0.6009 - auc: 0.8695 - val_loss: 0.3783 - val_precision: 0.6619 - val_recall: 0.6765 - val_auc: 0.8797
# Epoch 51/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3907 - precision: 0.6733 - recall: 0.6059 - auc: 0.8698 - val_loss: 0.3773 - val_precision: 0.6650 - val_recall: 0.6729 - val_auc: 0.8804
# Epoch 52/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3900 - precision: 0.6741 - recall: 0.6035 - auc: 0.8704 - val_loss: 0.3766 - val_precision: 0.6642 - val_recall: 0.6802 - val_auc: 0.8809
# Epoch 53/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3889 - precision: 0.6765 - recall: 0.6103 - auc: 0.8713 - val_loss: 0.3757 - val_precision: 0.6622 - val_recall: 0.6900 - val_auc: 0.8816
# Epoch 54/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3887 - precision: 0.6754 - recall: 0.6086 - auc: 0.8715 - val_loss: 0.3746 - val_precision: 0.6662 - val_recall: 0.6848 - val_auc: 0.8824
# Epoch 55/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3879 - precision: 0.6759 - recall: 0.6092 - auc: 0.8720 - val_loss: 0.3739 - val_precision: 0.6642 - val_recall: 0.6913 - val_auc: 0.8827
# Epoch 56/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3870 - precision: 0.6759 - recall: 0.6129 - auc: 0.8726 - val_loss: 0.3732 - val_precision: 0.6664 - val_recall: 0.6926 - val_auc: 0.8834
# Epoch 57/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3866 - precision: 0.6752 - recall: 0.6138 - auc: 0.8729 - val_loss: 0.3719 - val_precision: 0.6696 - val_recall: 0.6877 - val_auc: 0.8842
# Epoch 58/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3852 - precision: 0.6788 - recall: 0.6157 - auc: 0.8741 - val_loss: 0.3716 - val_precision: 0.6654 - val_recall: 0.7036 - val_auc: 0.8845
# Epoch 59/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3852 - precision: 0.6764 - recall: 0.6172 - auc: 0.8739 - val_loss: 0.3707 - val_precision: 0.6673 - val_recall: 0.7018 - val_auc: 0.8851
# Epoch 60/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3839 - precision: 0.6774 - recall: 0.6215 - auc: 0.8750 - val_loss: 0.3695 - val_precision: 0.6707 - val_recall: 0.6961 - val_auc: 0.8855
# Epoch 61/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3832 - precision: 0.6779 - recall: 0.6224 - auc: 0.8756 - val_loss: 0.3696 - val_precision: 0.6675 - val_recall: 0.7093 - val_auc: 0.8861
# Epoch 62/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3824 - precision: 0.6777 - recall: 0.6241 - auc: 0.8761 - val_loss: 0.3692 - val_precision: 0.6645 - val_recall: 0.7193 - val_auc: 0.8865
# Epoch 63/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3829 - precision: 0.6771 - recall: 0.6263 - auc: 0.8757 - val_loss: 0.3682 - val_precision: 0.6662 - val_recall: 0.7153 - val_auc: 0.8871
# Epoch 64/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3822 - precision: 0.6773 - recall: 0.6258 - auc: 0.8763 - val_loss: 0.3677 - val_precision: 0.6654 - val_recall: 0.7218 - val_auc: 0.8875
# Epoch 65/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3819 - precision: 0.6761 - recall: 0.6274 - auc: 0.8764 - val_loss: 0.3666 - val_precision: 0.6702 - val_recall: 0.7141 - val_auc: 0.8880
# Epoch 66/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3812 - precision: 0.6768 - recall: 0.6282 - auc: 0.8771 - val_loss: 0.3655 - val_precision: 0.6727 - val_recall: 0.7135 - val_auc: 0.8886
# Epoch 67/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3799 - precision: 0.6805 - recall: 0.6326 - auc: 0.8779 - val_loss: 0.3657 - val_precision: 0.6686 - val_recall: 0.7219 - val_auc: 0.8886
# Epoch 68/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3806 - precision: 0.6767 - recall: 0.6323 - auc: 0.8772 - val_loss: 0.3647 - val_precision: 0.6722 - val_recall: 0.7148 - val_auc: 0.8888
# Epoch 69/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3799 - precision: 0.6774 - recall: 0.6327 - auc: 0.8778 - val_loss: 0.3641 - val_precision: 0.6722 - val_recall: 0.7189 - val_auc: 0.8894
# Epoch 70/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3782 - precision: 0.6798 - recall: 0.6361 - auc: 0.8792 - val_loss: 0.3640 - val_precision: 0.6697 - val_recall: 0.7237 - val_auc: 0.8897
# Epoch 71/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3785 - precision: 0.6788 - recall: 0.6336 - auc: 0.8787 - val_loss: 0.3637 - val_precision: 0.6695 - val_recall: 0.7231 - val_auc: 0.8897
# Epoch 72/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3780 - precision: 0.6788 - recall: 0.6377 - auc: 0.8793 - val_loss: 0.3630 - val_precision: 0.6725 - val_recall: 0.7200 - val_auc: 0.8902
# Epoch 73/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3769 - precision: 0.6812 - recall: 0.6373 - auc: 0.8799 - val_loss: 0.3631 - val_precision: 0.6680 - val_recall: 0.7333 - val_auc: 0.8904
# Epoch 74/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3760 - precision: 0.6820 - recall: 0.6424 - auc: 0.8805 - val_loss: 0.3623 - val_precision: 0.6699 - val_recall: 0.7341 - val_auc: 0.8911
# Epoch 75/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3764 - precision: 0.6806 - recall: 0.6414 - auc: 0.8803 - val_loss: 0.3621 - val_precision: 0.6710 - val_recall: 0.7280 - val_auc: 0.8913
# Epoch 76/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3754 - precision: 0.6811 - recall: 0.6438 - auc: 0.8810 - val_loss: 0.3613 - val_precision: 0.6725 - val_recall: 0.7252 - val_auc: 0.8913
# Epoch 77/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3755 - precision: 0.6820 - recall: 0.6466 - auc: 0.8809 - val_loss: 0.3605 - val_precision: 0.6750 - val_recall: 0.7253 - val_auc: 0.8919
# Epoch 78/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3755 - precision: 0.6822 - recall: 0.6422 - auc: 0.8810 - val_loss: 0.3616 - val_precision: 0.6676 - val_recall: 0.7380 - val_auc: 0.8916
# Epoch 79/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3745 - precision: 0.6809 - recall: 0.6471 - auc: 0.8815 - val_loss: 0.3602 - val_precision: 0.6726 - val_recall: 0.7318 - val_auc: 0.8921
# Epoch 80/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3749 - precision: 0.6815 - recall: 0.6481 - auc: 0.8814 - val_loss: 0.3596 - val_precision: 0.6744 - val_recall: 0.7323 - val_auc: 0.8923
# Epoch 81/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3735 - precision: 0.6813 - recall: 0.6489 - auc: 0.8824 - val_loss: 0.3594 - val_precision: 0.6740 - val_recall: 0.7329 - val_auc: 0.8925
# Epoch 82/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3738 - precision: 0.6813 - recall: 0.6476 - auc: 0.8820 - val_loss: 0.3592 - val_precision: 0.6750 - val_recall: 0.7303 - val_auc: 0.8926
# Epoch 83/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3728 - precision: 0.6839 - recall: 0.6479 - auc: 0.8828 - val_loss: 0.3583 - val_precision: 0.6772 - val_recall: 0.7245 - val_auc: 0.8930
# Epoch 84/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3719 - precision: 0.6845 - recall: 0.6466 - auc: 0.8834 - val_loss: 0.3585 - val_precision: 0.6724 - val_recall: 0.7388 - val_auc: 0.8932
# Epoch 85/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3725 - precision: 0.6819 - recall: 0.6509 - auc: 0.8828 - val_loss: 0.3586 - val_precision: 0.6730 - val_recall: 0.7389 - val_auc: 0.8932
# Epoch 86/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3719 - precision: 0.6831 - recall: 0.6533 - auc: 0.8835 - val_loss: 0.3579 - val_precision: 0.6752 - val_recall: 0.7327 - val_auc: 0.8934
# Epoch 87/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3711 - precision: 0.6851 - recall: 0.6544 - auc: 0.8841 - val_loss: 0.3571 - val_precision: 0.6754 - val_recall: 0.7341 - val_auc: 0.8939
# Epoch 88/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3717 - precision: 0.6833 - recall: 0.6526 - auc: 0.8833 - val_loss: 0.3574 - val_precision: 0.6738 - val_recall: 0.7404 - val_auc: 0.8940
# Epoch 89/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3707 - precision: 0.6855 - recall: 0.6545 - auc: 0.8840 - val_loss: 0.3568 - val_precision: 0.6786 - val_recall: 0.7268 - val_auc: 0.8942
# Epoch 90/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3700 - precision: 0.6861 - recall: 0.6545 - auc: 0.8847 - val_loss: 0.3567 - val_precision: 0.6737 - val_recall: 0.7405 - val_auc: 0.8942
# Epoch 91/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3697 - precision: 0.6840 - recall: 0.6549 - auc: 0.8849 - val_loss: 0.3563 - val_precision: 0.6735 - val_recall: 0.7402 - val_auc: 0.8944
# Epoch 92/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3703 - precision: 0.6850 - recall: 0.6554 - auc: 0.8843 - val_loss: 0.3565 - val_precision: 0.6752 - val_recall: 0.7377 - val_auc: 0.8944
# Epoch 93/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3702 - precision: 0.6849 - recall: 0.6581 - auc: 0.8845 - val_loss: 0.3562 - val_precision: 0.6755 - val_recall: 0.7382 - val_auc: 0.8945
# Epoch 94/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3693 - precision: 0.6848 - recall: 0.6567 - auc: 0.8850 - val_loss: 0.3571 - val_precision: 0.6693 - val_recall: 0.7472 - val_auc: 0.8942
# Epoch 95/300
# 2511/2511 [==============================] - 8s 3ms/step - loss: 0.3686 - precision: 0.6856 - recall: 0.6614 - auc: 0.8855 - val_loss: 0.3566 - val_precision: 0.6729 - val_recall: 0.7412 - val_auc: 0.8944
# Epoch 96/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3680 - precision: 0.6850 - recall: 0.6603 - auc: 0.8860 - val_loss: 0.3545 - val_precision: 0.6801 - val_recall: 0.7295 - val_auc: 0.8949
# Epoch 97/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3687 - precision: 0.6845 - recall: 0.6590 - auc: 0.8855 - val_loss: 0.3557 - val_precision: 0.6735 - val_recall: 0.7428 - val_auc: 0.8948
# Epoch 98/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3685 - precision: 0.6851 - recall: 0.6572 - auc: 0.8856 - val_loss: 0.3544 - val_precision: 0.6789 - val_recall: 0.7358 - val_auc: 0.8954
# Epoch 99/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3688 - precision: 0.6877 - recall: 0.6585 - auc: 0.8856 - val_loss: 0.3549 - val_precision: 0.6754 - val_recall: 0.7397 - val_auc: 0.8952
# Epoch 100/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3675 - precision: 0.6854 - recall: 0.6630 - auc: 0.8861 - val_loss: 0.3552 - val_precision: 0.6735 - val_recall: 0.7467 - val_auc: 0.8954
# Epoch 101/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3681 - precision: 0.6851 - recall: 0.6625 - auc: 0.8858 - val_loss: 0.3551 - val_precision: 0.6719 - val_recall: 0.7478 - val_auc: 0.8954
# Epoch 102/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3674 - precision: 0.6843 - recall: 0.6631 - auc: 0.8863 - val_loss: 0.3541 - val_precision: 0.6738 - val_recall: 0.7444 - val_auc: 0.8958
# Epoch 103/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3669 - precision: 0.6864 - recall: 0.6633 - auc: 0.8867 - val_loss: 0.3535 - val_precision: 0.6772 - val_recall: 0.7396 - val_auc: 0.8960
# Epoch 104/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3666 - precision: 0.6878 - recall: 0.6641 - auc: 0.8869 - val_loss: 0.3536 - val_precision: 0.6754 - val_recall: 0.7443 - val_auc: 0.8962
# Epoch 105/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3664 - precision: 0.6886 - recall: 0.6629 - auc: 0.8872 - val_loss: 0.3541 - val_precision: 0.6759 - val_recall: 0.7423 - val_auc: 0.8959
# Epoch 106/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3661 - precision: 0.6876 - recall: 0.6631 - auc: 0.8871 - val_loss: 0.3537 - val_precision: 0.6759 - val_recall: 0.7449 - val_auc: 0.8961
# Epoch 107/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3659 - precision: 0.6877 - recall: 0.6659 - auc: 0.8872 - val_loss: 0.3536 - val_precision: 0.6753 - val_recall: 0.7422 - val_auc: 0.8961
# Epoch 108/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3658 - precision: 0.6874 - recall: 0.6657 - auc: 0.8873 - val_loss: 0.3531 - val_precision: 0.6755 - val_recall: 0.7453 - val_auc: 0.8963
# Epoch 109/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3657 - precision: 0.6871 - recall: 0.6658 - auc: 0.8875 - val_loss: 0.3529 - val_precision: 0.6770 - val_recall: 0.7448 - val_auc: 0.8965
# Epoch 110/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3655 - precision: 0.6871 - recall: 0.6655 - auc: 0.8875 - val_loss: 0.3528 - val_precision: 0.6770 - val_recall: 0.7439 - val_auc: 0.8964
# Epoch 111/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3651 - precision: 0.6881 - recall: 0.6653 - auc: 0.8878 - val_loss: 0.3529 - val_precision: 0.6744 - val_recall: 0.7479 - val_auc: 0.8963
# Epoch 112/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3652 - precision: 0.6860 - recall: 0.6665 - auc: 0.8876 - val_loss: 0.3528 - val_precision: 0.6775 - val_recall: 0.7420 - val_auc: 0.8965
# Epoch 113/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3656 - precision: 0.6873 - recall: 0.6640 - auc: 0.8874 - val_loss: 0.3527 - val_precision: 0.6762 - val_recall: 0.7498 - val_auc: 0.8968
# Epoch 114/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3642 - precision: 0.6887 - recall: 0.6678 - auc: 0.8884 - val_loss: 0.3517 - val_precision: 0.6801 - val_recall: 0.7384 - val_auc: 0.8970
# Epoch 115/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3650 - precision: 0.6883 - recall: 0.6666 - auc: 0.8880 - val_loss: 0.3522 - val_precision: 0.6767 - val_recall: 0.7513 - val_auc: 0.8969
# Epoch 116/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3644 - precision: 0.6885 - recall: 0.6681 - auc: 0.8880 - val_loss: 0.3529 - val_precision: 0.6743 - val_recall: 0.7571 - val_auc: 0.8973
# Epoch 117/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3639 - precision: 0.6891 - recall: 0.6677 - auc: 0.8887 - val_loss: 0.3514 - val_precision: 0.6793 - val_recall: 0.7424 - val_auc: 0.8972
# Epoch 118/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3641 - precision: 0.6879 - recall: 0.6695 - auc: 0.8883 - val_loss: 0.3515 - val_precision: 0.6783 - val_recall: 0.7461 - val_auc: 0.8973
# Epoch 119/300
# 2511/2511 [==============================] - 10s 4ms/step - loss: 0.3637 - precision: 0.6891 - recall: 0.6663 - auc: 0.8888 - val_loss: 0.3522 - val_precision: 0.6756 - val_recall: 0.7553 - val_auc: 0.8973
# Epoch 120/300
# 2511/2511 [==============================] - 8s 3ms/step - loss: 0.3630 - precision: 0.6880 - recall: 0.6692 - auc: 0.8890 - val_loss: 0.3522 - val_precision: 0.6746 - val_recall: 0.7560 - val_auc: 0.8972
# Epoch 121/300
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3626 - precision: 0.6887 - recall: 0.6698 - auc: 0.8893 - val_loss: 0.3525 - val_precision: 0.6739 - val_recall: 0.7588 - val_auc: 0.8972
# Epoch 122/300
# 2495/2511 [============================>.] - ETA: 0s - loss: 0.3631 - precision: 0.6884 - recall: 0.6710 - auc: 0.8891Restoring model weights from the end of the best epoch: 117.
# 2511/2511 [==============================] - 7s 3ms/step - loss: 0.3628 - precision: 0.6886 - recall: 0.6711 - auc: 0.8892 - val_loss: 0.3523 - val_precision: 0.6714 - val_recall: 0.7645 - val_auc: 0.8975
# Epoch 00122: early stopping

# %%
os.mkdir(f"model/{created_time}_{loss}_{lr}_{batch_size}")
model.save(f'model/{created_time}_{loss}_{lr}_{batch_size}/exercise_model.h5')
# Out:
# c:\Users\wooyong\anaconda3\envs\kwix\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
plt.figure(figsize=(25,4), facecolor='white')
plt.subplot(1,3,1)
pd.Series(history.history['loss']).plot(logy=True)
pd.Series(history.history['val_loss']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Train Error")

plt.subplot(1,3,2)
pd.Series(history.history['recall']).plot(logy=True)
pd.Series(history.history['val_recall']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Recall")

plt.subplot(1,3,3)
pd.Series(history.history['precision']).plot(logy=True)
pd.Series(history.history['val_precision']).plot(logy=True)
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.savefig(f"model/{created_time}_{loss}_{lr}_{batch_size}/metrics.png")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

label_pre = model.predict([x_val, y_val])


# #Create confusion matrix and normalizes it over predicted (columns)
# label = np.argmax(label_val, axis = 1)

label_pre = np.round(label_pre,0)
result = confusion_matrix(label_val, label_pre)
print(result)

import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
plt.figure(facecolor='white')
ax = sns.heatmap(result, annot=True,fmt='d',cmap='Blues',norm=LogNorm())
plt.title('Heatmap', fontsize=20)
plt.savefig(f"model/{created_time}_{loss}_{lr}_{batch_size}/heatmap.png")
plt.show()
# Out:
# [[25521  3803]
#  [ 2795  8057]]
