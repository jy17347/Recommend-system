# %%
import numpy as np
import pandas as pd
import os, time
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
height = 180
weight = 85
sex = 1
age = 20
bmi = weight*10000 /height**2 
ability = 4
height = (height-170)/30
weight = (weight-70)/30
age = (age-30)/30
bmi = (bmi-30)/20
input_data = [[height, weight, sex, age, bmi, ability]]
input_data
# Out:
# [[0.3333333333333333, 0.5, 1, -0.3333333333333333, -0.1882716049382717, 4]]

# %%
dataset_dir = 'C://project//dataset/kwix/curation'
user_data = pd.read_csv(dataset_dir + '/user.csv')
user_data = user_data.to_numpy()
user_data[:,1] = (user_data[:,1]-170)/30
user_data[:,2] = (user_data[:,2]-70)/30
user_data[:,4] = (user_data[:,4]-30)/30
user_data[:,5] = (user_data[:,5]-30)/20
user_similarity = np.corrcoef(input_data,user_data[:,1:])[0,1:]
user_similarity
# Out:
# array([0.99044981, 0.97900025, 0.94566097, 0.9525501 , 0.99836038,
#        0.94555515, 0.98260152, 0.90964213, 0.9587514 , 0.9206933 ,
#        0.76709485, 0.78646674, 0.99350682, 0.99967703, 0.96261132,
#        0.88791451, 0.73159055, 0.88430451, 0.88998961, 0.99787225,
#        0.88677345, 0.93531926, 0.92136435, 0.93277536, 0.94418774,
#        0.96990295, 0.98459142, 0.9933784 , 0.94018077, 0.915149  ,
#        0.9508887 , 0.99806092, 0.92978844, 0.81878178, 0.9263759 ,
#        0.94294273, 0.94126573, 0.77793787, 0.89101891, 0.85157894,
#        0.84820037, 0.98039926, 0.90088097, 0.98143797, 0.78765824,
#        0.88661185, 0.9076279 , 0.98050843, 0.99431479, 0.75089371,
#        0.99453545, 0.94716117, 0.94214837, 0.9531711 , 0.84235374,
#        0.22706205, 0.75388281, 0.83803993, 0.95423292, 0.98517783,
#        0.93171527, 0.88196613, 0.36664032, 0.99959343, 0.95617187,
#        0.70595459, 0.96649542, 0.97383008, 0.88336707, 0.86646203,
#        0.40544422, 0.76679914, 0.99087761, 0.95838797, 0.92840284,
#        0.97788403, 0.99048066, 0.94722635, 0.74816238, 0.97001391,
#        0.8702125 , 0.93042111, 0.8485149 , 0.90533114, 0.82801642,
#        0.99002299, 0.96284538, 0.71715199, 0.86229312, 0.91722976,
#        0.95214884, 0.8319638 , 0.71026282, 0.98127299, 0.84070403,
#        0.87694858, 0.71628952, 0.82494634, 0.89757982, 0.9088719 ,
#        0.9964941 , 0.97970421, 0.93657036, 0.8197036 , 0.99601615,
#        0.95741111, 0.87407671, 0.26125332, 0.96318277, 0.86064892,
#        0.95611058, 0.27431053, 0.95856874, 0.88481177, 0.75544366,
#        0.91279243, 0.8937183 , 0.97315939, 0.73842079, 0.99603259,
#        0.84758079, 0.84199774, 0.86567626, 0.90638559, 0.77456351,
#        0.74682799, 0.90392015, 0.97466907, 0.86555255, 0.85971995,
#        0.95555015, 0.90282353, 0.86734466, 0.98635398, 0.9726034 ,
#        0.86654396, 0.98068002, 0.93256536, 0.94519154, 0.95777329,
#        0.89107639, 0.83261844, 0.91414099, 0.88326881, 0.85891367,
#        0.98889408, 0.86267393, 0.82410811, 0.84830107, 0.887067  ,
#        0.93847464, 0.80121539, 0.89412954, 0.88964289, 0.81817751,
#        0.98303375, 0.7377032 , 0.95300634, 0.9629891 , 0.80194167,
#        0.91903337, 0.95732507, 0.90374258, 0.98258281, 0.9030971 ,
#        0.991373  , 0.9155341 , 0.80693325, 0.85962609, 0.96251264,
#        0.68265355, 0.9906689 , 0.73026846, 0.9028726 , 0.96512411,
#        0.84142218, 0.70874848, 0.38632775, 0.97516693, 0.89678937,
#        0.9569473 , 0.67777898, 0.84247212, 0.92025046, 0.96263821,
#        0.8008297 , 0.97532516, 0.97980936, 0.93854807, 0.80692308,
#        0.90521597, 0.96244557, 0.99013161, 0.99424874, 0.82579002,
#        0.93858553, 0.95256355, 0.94554132, 0.72125261, 0.69513598,
#        0.90848253, 0.88818579, 0.98444022, 0.86312017, 0.92382908,
#        0.98385047, 0.7377032 , 0.96227597, 0.91707322, 0.73514967,
#        0.9368562 , 0.84895281, 0.88402834, 0.82065314, 0.99224546,
#        0.95898849, 0.98023075, 0.91727894, 0.84275202, 0.91538295,
#        0.88794724, 0.82056883, 0.74963848, 0.77696312, 0.95074912,
#        0.98390542, 0.95356449, 0.74989245, 0.96137133, 0.99045049,
#        0.96619817, 0.86013695, 0.96598318, 0.85058878, 0.26300686,
#        0.85149095, 0.90565228, 0.80228974, 0.92623022, 0.88452295,
#        0.34481318, 0.89510355, 0.88079834, 0.88190669, 0.75433801,
#        0.90708201, 0.89124773, 0.74583215, 0.91059771, 0.90974205,
#        0.80615409, 0.99054813, 0.9827562 , 0.93361813, 0.6726326 ,
#        0.88683026, 0.8296708 , 0.75476464, 0.91315631, 0.74007736,
#        0.87007714, 0.85332742, 0.94903894, 0.89326493, 0.74300401,
#        0.9643354 , 0.96159047, 0.87586589, 0.80416316, 0.73159055,
#        0.74357216, 0.93046775, 0.95839601, 0.73289345, 0.81291092,
#        0.98629633, 0.91346854, 0.8651495 , 0.84333969, 0.80710479,
#        0.81680656, 0.95728033, 0.92919875, 0.97622273, 0.89253446,
#        0.82867332, 0.92608173, 0.88183835, 0.88340185, 0.91656752])

# %%
chest_df = pd.read_csv(dataset_dir +'/chest.csv')
chest = pd.read_csv(dataset_dir +'/chest.csv').to_numpy()[:, 1:]
lower = pd.read_csv(dataset_dir + '/lower_body.csv').to_numpy()[:, 1:]
abdom = pd.read_csv(dataset_dir + '/abdominals.csv').to_numpy()[:, 1:]

# %%
mean_probability = np.dot(user_similarity, chest) / user_similarity.sum()
mean_probability
# Out:
# array([0.00665107, 0.00769876, 0.00723921, 0.18481129, 0.22631486,
#        0.23819849, 0.22789556, 0.16743819, 0.15044128, 0.15088905,
#        0.15983932, 0.16337196, 0.15727566, 0.15193529, 1.        ])

# %%
x = (mean_probability.argsort())[::-1]
print(x)
# Out:
# [14  5  6  4  3  7 11 10 12 13  9  8  1  2  0]

# %%
chest_df.columns[x[0:5] + 1]
# Out:
# Index(['벤트오버덤벨레이즈', '인클라인푸쉬업', '바이셉스푸쉬업', '디클라인푸쉬업', '업앤다운푸쉬업'], dtype='object')
